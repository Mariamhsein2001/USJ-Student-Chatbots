# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.23)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 52.9 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20250506

# %%
import re
import json

def extract_courses_from_lines(lines):
    course_pattern = re.compile(
        r"^(?P<code>[0-9A-Z\s]{4,14}\d)\s+(?P<title>.+?)\s+(?P<credits>\d+)\s*Cr\.?", re.UNICODE
    )

    prereq_pattern = re.compile(r"^Prérequis ?: (?P<prerequisites>.+)", re.IGNORECASE)

    courses = []
    current_course = None

    def finalize():
        nonlocal current_course
        if current_course:
            print("Finalizing course:", current_course["code"])
            courses.append(current_course.copy())
            current_course = None


    for line in lines:
        line = line.strip()
        if not line:
            continue

        match = course_pattern.match(line)
        if match:
          finalize()
          code_raw = match.group("code")
          normalized_code = re.sub(r"\s+", "", code_raw)  # Remove spaces
          current_course = {
              "code": normalized_code,
              "title": match.group("title").strip(),
              "credits": int(match.group("credits")),
              "description": "",
              "prerequisites": None
          }
        elif current_course:
            prereq_match = prereq_pattern.match(line)
            if prereq_match:
                current_course["prerequisites"] = prereq_match.group("prerequisites")
            else:
                current_course["description"] += " " + line.strip()

    finalize()
    return courses

def is_course_section_header(line):
    if line.startswith("### ") or line.startswith("##### "):
        header = line.lower()
        print(f"Checking header for courses: {header}")
        return "description des cours" in header or "descriptives des cours" in header
    return False

def extract_courses_from_markdown(markdown_text):
    lines = markdown_text.splitlines()
    all_departments = {}
    current_department = None
    current_subdepartment = None
    collecting = False
    buffer = []

    for line in lines:
        line = line.strip()

        # --- Detect Department ---
        if line.startswith("## "):
            # Flush any buffer from previous collection
            if collecting and buffer:
                if current_department:
                    if current_department == "Département des Etudes Doctorales" and current_subdepartment:
                        print(f"Flushing Doctorat Master: {current_subdepartment}")
                        all_departments[current_department][current_subdepartment]["courses"].extend(extract_courses_from_lines(buffer))
                    else:
                        all_departments[current_department].extend(extract_courses_from_lines(buffer))
                buffer = []
                collecting = False

            current_department = line[3:].strip()
            current_subdepartment = None
            print(f"New department: {current_department}")
            if current_department == "Département des Etudes Doctorales":
                all_departments[current_department] = {}
            else:
                all_departments[current_department] = []
            continue

        # --- Doctorate Master Header ---
        if current_department == "Département des Etudes Doctorales" and line.startswith("### Master"):
            # Flush buffer if switching master
            if collecting and buffer and current_subdepartment:
                all_departments[current_department][current_subdepartment]["courses"].extend(extract_courses_from_lines(buffer))
                buffer = []

            current_subdepartment = line[4:].strip()
            print(f"Doctorat Master Found: {current_subdepartment}")
            all_departments[current_department][current_subdepartment] = {"courses": []}
            collecting = False
            continue

        # --- Doctorate Course Section Header ---
        if current_department == "Département des Etudes Doctorales" and line.lower().startswith("##### contenu des cours") or line.lower().startswith("##### course content"):
            print(f"Found 'Contenu des Cours' in {current_subdepartment}")
            collecting = True
            buffer = []
            continue

        # End of a content block in Doctorate Master
        if current_department == "Département des Etudes Doctorales" and line.startswith("##### ") and collecting:
            print(f"End of 'Contenu des Cours' in {current_subdepartment}")
            if current_subdepartment and buffer:
                all_departments[current_department][current_subdepartment]["courses"].extend(extract_courses_from_lines(buffer))
            buffer = []
            collecting = False
            continue

        # --- Standard Course Section Header ---
        elif is_course_section_header(line):
            print(f"Found course section header: {line}")
            if collecting and buffer and current_department:
                all_departments[current_department].extend(extract_courses_from_lines(buffer))
                buffer = []
            collecting = True
            continue

        # --- End collecting on any other header ---
        elif (line.startswith("### ") or line.startswith("##### ")) and collecting:
            print(f"Hit new header {line} while collecting. Flushing buffer and stopping collection.")
            if current_department:
                if current_department == "Département des Etudes Doctorales" and current_subdepartment:
                    all_departments[current_department][current_subdepartment]["courses"].extend(extract_courses_from_lines(buffer))
                elif isinstance(all_departments[current_department], list):
                    all_departments[current_department].extend(extract_courses_from_lines(buffer))
            buffer = []
            collecting = False
            continue

        # --- Collect lines ---
        elif collecting:
            buffer.append(line)

    # --- Final flush ---
    if collecting and buffer:
        if current_department:
            if current_department == "Département des Etudes Doctorales" and current_subdepartment:
                print(f"Final flush for Doctorat Master {current_subdepartment}")
                all_departments[current_department][current_subdepartment]["courses"].extend(extract_courses_from_lines(buffer))
            elif isinstance(all_departments[current_department], list):
                print(f"Final flush for department {current_department}")
                all_departments[current_department].extend(extract_courses_from_lines(buffer))
        else:
            print("Warning: No current department set at final flush.")

    return all_departments

# Example usage
if __name__ == "__main__":
    with open("/content/Catalogue_ESIB_2022-2023.md", "r", encoding="utf-8") as f:
        markdown = f.read()

    dept_courses = extract_courses_from_markdown(markdown)

    with open("courses_by_department.json", "w", encoding="utf-8") as f:
        json.dump(dept_courses, f, ensure_ascii=False, indent=2)

    print(f"✅ Extracted courses from {len(dept_courses)} departments.")
# Out:
# New department: École Supérieure d’Ingénieurs de Beyrouth (ESIB)
# Checking header for courses: ### historique
# Checking header for courses: ### mission de l’esib
# Checking header for courses: ### vision de l’esib
# Checking header for courses: ### direction
# Checking header for courses: ### administration
# Checking header for courses: ### corps professoral
# Checking header for courses: ### diplômes
# Checking header for courses: ### admission
# Checking header for courses: ##### admission en première année ingénieur (classe de mathématiques supérieures)
# Checking header for courses: ##### admission par transfert d’une autre institution
# Checking header for courses: ##### admission en master
# Checking header for courses: ### frais de scolarité
# Checking header for courses: ### organisation des enseignements
# Checking header for courses: ### vie associative
# Checking header for courses: ### aumônerie
# New department: Département des Classes Préparatoires
# Checking header for courses: ### responsable : melhem el helou
# Checking header for courses: ### corps professoral
# Checking header for courses: ### objectifs
# Checking header for courses: ### débouchés
# Checking header for courses: ### programmes et formations
# Checking header for courses: ### programme préparatoire génie chimique et pétrochimique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme préparatoire génie civil
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme préparatoire génie électrique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme préparatoire génie informatique et communications
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme préparatoire génie mécanique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme concours génie chimique et pétrochimique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme concours génie civil
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme concours génie électrique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme concours génie informatique et communications
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme concours génie mécanique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### descriptives des cours
# Found course section header: ### Descriptives des Cours
# Finalizing course: 020AL1CI2
# Finalizing course: 020AL2CI3
# Finalizing course: 020AL3CI4
# Finalizing course: 020ALBNI3
# Finalizing course: 020ALBNI3
# Finalizing course: 020AA1CI2
# Finalizing course: 020AA1NI2
# Finalizing course: 020AN2CI3
# Finalizing course: 020AN2NI4
# Finalizing course: 020AN3CI4
# Finalizing course: 020ANGCI1
# Finalizing course: 020ANGNI1
# Finalizing course: 020ATONI2
# Finalizing course: 020CDFNI4
# Finalizing course: 020CHACI3
# Finalizing course: 020CHGCI1
# Finalizing course: 020CHGNI1
# Finalizing course: 020CIOCI4
# Finalizing course: 020CITNI4
# Finalizing course: 020CORNI3
# Finalizing course: 020CORCI4
# Finalizing course: 020CIFCI4
# Finalizing course: 020CIFNI4
# Finalizing course: 020CIHNI4
# Finalizing course: 020CMTNI1
# Finalizing course: 020CPCNI1
# Finalizing course: 020COANI4
# Finalizing course: 020DAINI4
# Finalizing course: 020DISCI4
# Finalizing course: 020DISNI4
# Finalizing course: 020EMECI3
# Finalizing course: 020EMENI3
# Finalizing course: 020FR1CI2
# Finalizing course: 020FR2CI3
# Finalizing course: 020GELCI4
# Finalizing course: 020GELNI4
# Finalizing course: 020INMCI2
# Finalizing course: 020INMNI2
# Finalizing course: 020IF1NI2
# Finalizing course: 020IF1CI2
# Finalizing course: 020IF2NI3
# Finalizing course: 020IF2CI3
# Finalizing course: 020IF3NI4
# Finalizing course: 020IF3CI4
# Finalizing course: 020IMFNI4
# Finalizing course: 020IMFCI4
# Finalizing course: 020IIFNI1
# Finalizing course: 020ISMNI2
# Finalizing course: 020GSCNI2
# Finalizing course: 020GSCCI1
# Finalizing course: 020MADCI1
# Finalizing course: 020MADNI1
# Finalizing course: 020MATNI4
# Finalizing course: 020MC1CI1
# Finalizing course: 020MC1NI1
# Finalizing course: 020MC2CI3
# Finalizing course: 020MC2NI3
# Finalizing course: 020BIMNI4
# Finalizing course: 020OPTCI3
# Finalizing course: 020OPTNI3
# Finalizing course: 020PHONI3
# Finalizing course: 020PHQCI4
# Finalizing course: 020PRBNI4
# Finalizing course: 020PIINI4
# Finalizing course: 020PIICI4
# Finalizing course: 020SPHCI1
# Finalizing course: 020SPHNI1
# Finalizing course: 020STACI4
# Finalizing course: 020STANI4
# Finalizing course: 020STMNI4
# Finalizing course: 020STMCI4
# Finalizing course: 020STFNI2
# Finalizing course: 020SRLNI4
# Finalizing course: 020SRLCI4
# Finalizing course: 020TEDCI4
# Finalizing course: 020TEDNI4
# Finalizing course: 020TH1CI2
# Finalizing course: 020TH1NI2
# Finalizing course: 020TH2CI4
# Finalizing course: 020TH2NI3
# Finalizing course: 020THENI3
# Finalizing course: 020TOGCI4
# Finalizing course: 020TOGNI4
# Finalizing course: 020TRSCI3
# Finalizing course: 020TIPCI4
# Finalizing course: 020TCGCI2
# Finalizing course: 020TCGNI2
# Finalizing course: 020PCONI4
# Finalizing course: 020PP1CI2
# Finalizing course: 020PP1NI2
# Finalizing course: 020PP2CI3
# Finalizing course: 020PP2NI3
# New department: Département Génie Électrique et Mécanique
# Checking header for courses: ### responsable : flavia khatounian el rajji
# Checking header for courses: ### corps professoral
# Checking header for courses: ### objectifs
# Checking header for courses: ### débouchés
# Checking header for courses: ### spécialisation et recherche
# Checking header for courses: ### programmes et options
# Checking header for courses: ### programme génie électrique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme génie informatique et communications
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### programme génie mécanique
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ### description des cours
# Found course section header: ### Description des Cours
# Finalizing course: 020AEVES4
# Finalizing course: 020ADUES3
# Finalizing course: 020ADWES4
# Finalizing course: 020ARDES3
# Finalizing course: 020ADPES3
# Finalizing course: 020ANRES4
# Finalizing course: 020ANMES5
# Finalizing course: 020ANGES4
# Finalizing course: 020APDES4
# Finalizing course: 020AROES3
# Finalizing course: 020ATIES5
# Finalizing course: 020AULES2
# Finalizing course: 020AUTES3
# Finalizing course: 020BDAES3
# Finalizing course: 020BDRES2
# Finalizing course: 020BEMES5
# Finalizing course: 020BIMES3
# Finalizing course: 020CM1ES3
# Finalizing course: 020CM2ES4
# Finalizing course: 020CEIES3
# Finalizing course: 020CL1ES3
# Finalizing course: 020CL2ES4
# Finalizing course: 020CLDES5
# Finalizing course: 020CTMES4
# Finalizing course: 020CONES3
# Finalizing course: 020CSFES3
# Finalizing course: 020CMPES5
# Finalizing course: 020CAOES2
# Finalizing course: 020CCIES4
# Finalizing course: 020CPMES3
# Finalizing course: 020CSMES4
# Finalizing course: 020SSMES3
# Finalizing course: 020CCCES3
# Finalizing course: 020CCAES4
# Finalizing course: 020CRYES4
# Finalizing course: 020DMOES4
# Finalizing course: 020DOMES3
# Finalizing course: 020DROES5
# Finalizing course: 020EEIES4
# Finalizing course: 020ELCES1
# Finalizing course: 020ELAES1
# Finalizing course: 020ELIES2
# Finalizing course: 020ELNES2
# Finalizing course: 020ETCES1
# Finalizing course: 020ELFES4
# Finalizing course: 020ERNES5
# Finalizing course: 020EVVES4
# Finalizing course: 020ENTES1
# Finalizing course: 020ETHES3
# Finalizing course: 020FDMES3
# Finalizing course: 020GPRES2
# Finalizing course: 020GLOES5
# Finalizing course: 020GDEES4
# Finalizing course: 020HYDES3
# Finalizing course: 020IPRES5
# Finalizing course: 020I3DES3
# Finalizing course: 020ISSES5
# Finalizing course: 020IDRES5
# Finalizing course: 020INMES5
# Finalizing course: 020INDES2
# Finalizing course: 020IE1ES2
# Finalizing course: 020IAEES5
# Finalizing course: 020IDCES4
# Finalizing course: 020IA2ES4
# Finalizing course: 020IA3ES4
# Finalizing course: 020IMEES1
# Finalizing course: 020INRES1
# Finalizing course: 020ISDES3
# Finalizing course: 020LFLES5
# Finalizing course: 020MLRES4
# Finalizing course: 020ME1ES2
# Finalizing course: 020ME2ES3
# Finalizing course: 020MNGES4
# Finalizing course: 020MNGES5
# Finalizing course: 020MF1ES1
# Finalizing course: 020MF2ES3
# Finalizing course: 020MMCES4
# Finalizing course: 020MMIES5
# Finalizing course: 020MENES1
# Finalizing course: 020MMDES4
# Finalizing course: 020MCOES3
# Finalizing course: 020MSDES1
# Finalizing course: 020MOTES4
# Finalizing course: 020OEPES5
# Finalizing course: 020OFPES4
# Finalizing course: 020PSRES4
# Finalizing course: 020PIRES5
# Finalizing course: 020PLBES4
# Finalizing course: 020PCOES4
# Finalizing course: 020PF1ES3
# Finalizing course: 020PF2ES4
# Finalizing course: 020PRNES4
# Finalizing course: 020PENES4
# Finalizing course: 020PCPES2
# Finalizing course: 020PFSES3
# Finalizing course: 020CPPES1
# Finalizing course: 020PPLES5
# Finalizing course: 020PWBES3
# Finalizing course: 020PFEES6
# Finalizing course: 020PRMES4
# Finalizing course: 020PGAES3
# Finalizing course: 020PCHES3
# Finalizing course: 020QOSES5
# Finalizing course: 020RPEES5
# Finalizing course: 020RESES5
# Finalizing course: 020ROPES5
# Finalizing course: 020RLIES4
# Finalizing course: 020REMES4
# Finalizing course: 020RM1ES2
# Finalizing course: 020RM2ES3
# Finalizing course: 020ROBES5
# Finalizing course: 020RBMES4
# Finalizing course: 020RCOES2
# Finalizing course: 020SMAES4
# Finalizing course: 020SPMES4
# Finalizing course: 020SYSES2
# Finalizing course: 020SSTES4
# Finalizing course: 020STGES5
# Finalizing course: 020STAES1
# Finalizing course: 020SDAES3
# Finalizing course: 020SMPES3
# Finalizing course: 020SPAES5
# Finalizing course: 020SSEES4
# Finalizing course: 020SEMES3
# Finalizing course: 020SCNES3
# Finalizing course: 020SYOES4
# Finalizing course: 020SFRES5
# Finalizing course: 020SMEES1
# Finalizing course: 020MEMES5
# Finalizing course: 020SNLES5
# Finalizing course: 020SSHES5
# Finalizing course: 020TCOES2
# Finalizing course: 020IDOES5
# Finalizing course: 020TPPES1
# Finalizing course: 020TICES5
# Finalizing course: 020TROES2
# Finalizing course: 020THSES2
# Finalizing course: 020TIMES4
# Finalizing course: 020TNSES3
# Finalizing course: 020TRCES2
# Finalizing course: 020TRBES3
# Finalizing course: 020VIBES2
# Finalizing course: 020VIRES5
# Finalizing course: 020VRTES4
# New department: Département Génie Civil et Environnement
# Checking header for courses: ### responsable : muhsin elie rahhal
# Checking header for courses: ### corps professoral
# Checking header for courses: ### objectifs
# Checking header for courses: ### débouchés
# Checking header for courses: ### programmes et formations
# Checking header for courses: ##### objectifs éducatifs du programme
# Checking header for courses: ##### compétences
# Checking header for courses: ##### exigences du programme
# Checking header for courses: ##### plan proposé
# Checking header for courses: ##### descriptives des cours
# Found course section header: ##### Descriptives des Cours
# Finalizing course: 020ACBGS5
# Finalizing course: 020SP2GS4
# Finalizing course: 020AVTGS4
# Finalizing course: 020ANNGS1
# Finalizing course: 020ANGGS4
# Finalizing course: 020AINGS4
# Finalizing course: 020ASTGS4
# Finalizing course: 020BAGGS5
# Finalizing course: 020ACTGS2
# Finalizing course: 020BEAGS3
# Finalizing course: 020BPEPGS5
# Finalizing course: 020PLSGS4
# Finalizing course: 020CHCGS4
# Finalizing course: 020ACIGS3
# Finalizing course: 020WRNGS1
# Finalizing course: 020CGAGS1
# Finalizing course: 020COCGS5
# Finalizing course: 020COSGS5
# Finalizing course: 020CTHGS4
# Finalizing course: 020INDGS4
# Finalizing course: 020CMMGS3
# Finalizing course: 020CATGS4
# Finalizing course: 020DESGS5
# Finalizing course: 020DEAGS3
# Finalizing course: 020DREGS3
# Finalizing course: 020DYSGS5
# Finalizing course: 020ECHGS4
# Finalizing course: 020ECGGS1
# Finalizing course: 020EFIGS4
# Finalizing course: 020GEIGS4
# Finalizing course: 020ENVGS1
# Finalizing course: 020ETHGS1
# Finalizing course: 020FOSGS3
# Finalizing course: 020EREGS2
# Finalizing course: 020GEPGS5
# Finalizing course: 020QUAGS3
# Finalizing course: 020GEFGS3
# Finalizing course: 020GRDGS4
# Finalizing course: 020HYDGS3
# Finalizing course: 020HSOGS5
# Finalizing course: 020HKAGS5
# Finalizing course: 020HYDGS5
# Finalizing course: 020HYSGS5
# Finalizing course: 020IMPGS4
# Finalizing course: 020TRAGS3
# Finalizing course: 020IRRGS4
# Finalizing course: 020BPRGS5
# Finalizing course: 020LEBGS1
# Finalizing course: 020CDAGS4
# Finalizing course: 020LOCGS5
# Finalizing course: 020LOGGS5
# Finalizing course: 020MAIGS1
# Finalizing course: 020MEFGS2
# Finalizing course: 020MMDGS1
# Finalizing course: 020MESGS2
# Finalizing course: 020MEAGS5
# Finalizing course: 020MOGGS5
# Finalizing course: 020OREGS4
# Finalizing course: 020OSBGS4
# Finalizing course: 020OUMGS5
# Finalizing course: 020OSPGS5
# Finalizing course: 020PLGGS5
# Finalizing course: 020PLCGS5
# Finalizing course: 020PGCGS2
# Finalizing course: 020PARGS1
# Finalizing course: 020PBAGS4
# Finalizing course: 020PBAGS6
# Finalizing course: 020PEAGS6
# Finalizing course: 020PTPGS6
# Finalizing course: 020PECGS4
# Finalizing course: 020FQSRS4
# Finalizing course: 020REMGS5
# Finalizing course: 020RESGS4
# Finalizing course: 020ASSGS4
# Finalizing course: 020RCGGS5
# Finalizing course: 020RDMGS2
# Finalizing course: 020ROUGS4
# Finalizing course: 020SEIGS5
# Finalizing course: 020STEGS5
# Finalizing course: 020STOGS1
# Finalizing course: 020STAGS2
# Finalizing course: 020STRGS4
# Finalizing course: 020GISGS3
# Finalizing course: 020AERGS3
# New department: Département Génie Chimique et Pétrochimique
# Checking header for courses: ### responsable : jihane nabil rahbani
# Checking header for courses: ### corps professoral
# Checking header for courses: ### objectifs
# Checking header for courses: ### débouchés
# Checking header for courses: ### objectifs éducatifs du programme
# Checking header for courses: ### compétences
# Checking header for courses: ### exigences du programme
# Checking header for courses: ### plan proposé
# Checking header for courses: ### descriptives des cours
# Found course section header: ### Descriptives des Cours
# Finalizing course: 020ANNCS1
# Finalizing course: 020AMTCS4
# Finalizing course: 020ASCCS5
# Finalizing course: 020ANGCS4
# Finalizing course: 020BRICS1
# Finalizing course: 020BRFCS3
# Finalizing course: 020CAOCS3
# Finalizing course: 020CHPCS2
# Finalizing course: 020CHICS2
# Finalizing course: 020CHTCS1
# Finalizing course: 020CCHCS1
# Finalizing course: 020COMCS2
# Finalizing course: 020CEPCS4
# Finalizing course: 020CPPCS4
# Finalizing course: 020TBICS5
# Finalizing course: 020CONCS3
# Finalizing course: 020DROCS2
# Finalizing course: 020DCPCS3
# Finalizing course: 020ECOCS2
# Finalizing course: 020ENPCS2
# Finalizing course: 020ETHCS1
# Finalizing course: 020FEACS5
# Finalizing course: 020GTHCS3
# Finalizing course: 020GEACS5
# Finalizing course: 020GDSS5
# Finalizing course: 020GEPCS4
# Finalizing course: 020GPRCS5
# Finalizing course: 020IBDCS1
# Finalizing course: 020IDRCS5
# Finalizing course: 020PROCS2
# Finalizing course: 020MNGCS2
# Finalizing course: 020MARCS2
# Finalizing course: 020MACCS4
# Finalizing course: 020MLTCS3
# Finalizing course: 020MEFCS2
# Finalizing course: 020MCECS3
# Finalizing course: 020MOSCS3
# Finalizing course: 020OPUCS3
# Finalizing course: 020PDTCS1
# Finalizing course: 020PFOCS5
# Finalizing course: 020PPCCS4
# Finalizing course: 020PRPCS3
# Finalizing course: 020PFECS6
# Finalizing course: 020PDPCS4
# Finalizing course: 020QHSCS2
# Finalizing course: 020RNICS2
# Finalizing course: 020ST1CS3
# Finalizing course: 020ST2CS5
# Finalizing course: 020STACS2
# Finalizing course: 020STMCS2
# Finalizing course: 020TBICS5
# Finalizing course: 020TESCS4
# Finalizing course: 020TMCCS4
# Finalizing course: 020TDFCS3
# Finalizing course: 020THCCS1
# Finalizing course: 020TEUCS5
# Finalizing course: 020GEPCS5
# New department: Département des Etudes Doctorales
# Checking header for courses: ### responsable : hadi kanaan
# Checking header for courses: ### objectifs
# Checking header for courses: ### programmes et formations
# Doctorat Master Found: Master en Data Sciences
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master en Data Sciences
# Finalizing course: 048DSARM3
# Finalizing course: 020CTDIM1
# Finalizing course: 020DVCOM3
# Finalizing course: 020INTDM2
# Finalizing course: 020IADMM1
# Finalizing course: 048DSTGM1
# Finalizing course: 048DSSIM1
# Finalizing course: 020STGEM4
# Finalizing course: 020LPEDM3
# Finalizing course: 020MLDLM3
# Finalizing course: 020IAMAM1
# Finalizing course: 020FOBDM2
# Finalizing course: 048DSPOM1
# Finalizing course: 048DSLRM1
# Finalizing course: 048MBCMM2
# Finalizing course: 020BDREM1
# Finalizing course: 048DSSBM1
# Finalizing course: 048DSTGM3
# Finalizing course: 020WEMIM3
# Doctorat Master Found: Master in Artificial Intelligence
# Checking header for courses: ##### general information
# Checking header for courses: ##### scientific and educational objectives
# Checking header for courses: ##### general organization
# Checking header for courses: ##### proposed curriculum
# Found 'Contenu des Cours' in Master in Artificial Intelligence
# Finalizing course: 020IARBM3
# Finalizing course: 020IACGM3
# Finalizing course: 020IACVM3
# Finalizing course: 020IACSM3
# Finalizing course: 020IAFIM3
# Finalizing course: 020IANLM3
# Finalizing course: 020IADMM1
# Finalizing course: 020IAAIM1
# Finalizing course: 020IAGTM2
# Finalizing course: 020IAGOM2
# Finalizing course: 020IAINM4
# Finalizing course: 020IALPM3
# Finalizing course: 020IAMLM2
# Finalizing course: 020IAMAM1
# Finalizing course: 020IABDM2
# Finalizing course: 020IAPCM2
# Finalizing course: 020IAOOM1
# Finalizing course: 020IASTM1
# Doctorat Master Found: Master en Energies Renouvelables
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master en Energies Renouvelables
# Finalizing course: MRER12M3
# Finalizing course: MRER00M3
# Finalizing course: MRER09M3
# Finalizing course: MRER04M3
# Finalizing course: MRER01M3
# Finalizing course: MRER02M3
# Finalizing course: MRER03M3
# Finalizing course: MRER06M3
# Finalizing course: MRER00M4
# Finalizing course: MRER11M3
# Finalizing course: MRER14M3
# Finalizing course: MRER07M3
# Finalizing course: MRER05M3
# Finalizing course: MRER10M3
# Finalizing course: MRER16M3
# Finalizing course: MRER08M3
# Doctorat Master Found: Master en Génie Electrique
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master en Génie Electrique
# Finalizing course: 020ANRMM2
# Finalizing course: 020ANGMM2
# Finalizing course: 020ASNMM3
# Finalizing course: 020BCMMM3
# Finalizing course: 020BEPMM3
# Finalizing course: 020CEIMM1
# Finalizing course: 020CAEMM3
# Finalizing course: 020CTMMM2
# Finalizing course: 020CA1MM1
# Finalizing course: 020CA2MM2
# Finalizing course: 020EPAMM3
# Finalizing course: 020EVVMM2
# Finalizing course: 020ME2MM1
# Finalizing course: 020MGEMM4
# Finalizing course: 020GE1MM1
# Finalizing course: 020GE2MM2
# Finalizing course: 020MCCMM3
# Finalizing course: 020RSDMM3
# Finalizing course: 020STEMM3
# Finalizing course: 020SMPMM1
# Finalizing course: 020SCNMM1
# Doctorat Master Found: Master en Management de la Sécurité Routière
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master en Management de la Sécurité Routière
# Finalizing course: 433SR81M1
# Finalizing course: 433SR73M1
# Finalizing course: 433SR79M1
# Finalizing course: 433SR22M1
# Finalizing course: 433SR72M1
# Finalizing course: 433SR82M1
# Finalizing course: 433SR75M1
# Finalizing course: 433SR80M1
# Finalizing course: 433SR71M1
# Finalizing course: 433SR70M1
# Finalizing course: 433SR77M1
# Finalizing course: 433SR76M1
# Finalizing course: 433SR26M2
# Finalizing course: 433SR98M2
# Doctorat Master Found: Master Oil and Gas: Exploration, Production & Management
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master Oil and Gas: Exploration, Production & Management
# Finalizing course: 020AMOGM1
# Finalizing course: 020ASOGM2
# Finalizing course: 020BPOGM1
# Finalizing course: 020BAOGM2
# Finalizing course: 020CAOGM2
# Finalizing course: 020DSOGM2
# Finalizing course: 020DWOGM3
# Finalizing course: 020FMOGM2
# Finalizing course: 020GFOGM3
# Finalizing course: 020GEOGM1
# Finalizing course: 020FMOGM1
# Finalizing course: 020FROGM2
# Finalizing course: 020LFOGM3
# Finalizing course: 020LPOGM2
# Finalizing course: 020MEOGM2
# Finalizing course: 020MAOGM1
# Finalizing course: 020MIOGM1
# Finalizing course: 020PGOGM3
# Finalizing course: 020POOGM2
# Finalizing course: 020PGOGM2
# Finalizing course: 020PMOGM3
# Finalizing course: 020RSOGM3
# Finalizing course: 020TSOGM3
# Finalizing course: 020SMOGM3
# Finalizing course: 020SFOGM3
# Finalizing course: 020THOGM1
# Finalizing course: 020TROGM4
# Finalizing course: 020UMOGM3
# Finalizing course: 020WLOGM3
# Doctorat Master Found: Master Sciences de l’Eau
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master Sciences de l’Eau
# Finalizing course: 020ASTMM3
# Finalizing course: 020BGCMM3
# Finalizing course: 020DECMM1
# Finalizing course: 020ELFMM2
# Finalizing course: 020EPCMM3
# Finalizing course: 020TRAMM1
# Finalizing course: 020CFTMM3
# Finalizing course: 020HYDMM1
# Finalizing course: 020HYOMM1
# Finalizing course: 020HYPMM3
# Finalizing course: 020HSTMM1
# Finalizing course: 020KARMM3
# Finalizing course: 020RESMM3
# Finalizing course: 020MEFMM2
# Finalizing course: 020MESMM2
# Finalizing course: 020MSEMM4
# Finalizing course: 020ACQMM1
# Finalizing course: 020SE1MM1
# Finalizing course: 020SE2MM2
# Finalizing course: 020TEUMM3
# Finalizing course: 020QESMM3
# Finalizing course: 020RDMMM2
# Finalizing course: 020VCLMM3
# Doctorat Master Found: Master Structure et Mécanique des Sols
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master Structure et Mécanique des Sols
# Finalizing course: 020BARMM1
# Finalizing course: 020EC2MM3
# Finalizing course: 020EC3MM3
# Finalizing course: 020CSAMM3
# Finalizing course: 020PLSMM1
# Finalizing course: 020COMMM3
# Finalizing course: 020CFOMM3
# Finalizing course: 020DYSMM3
# Finalizing course: 020DYNMM1
# Finalizing course: 020FOSMM1
# Finalizing course: 020MEFMM2
# Finalizing course: 020MESMM2
# Finalizing course: 020SM1MM1
# Finalizing course: 020PLCMM1
# Finalizing course: 020CISMM1
# Finalizing course: 020SISMM3
# Finalizing course: 020MSMMM4
# Finalizing course: 020SROMM3
# Finalizing course: 020STRMM2
# Doctorat Master Found: Master Télécommunications, Réseaux et Sécurité
# Checking header for courses: ##### présentation générale
# Checking header for courses: ##### objectifs scientifique et pédagogique
# Checking header for courses: ##### organisation générale
# Checking header for courses: ##### plan proposé
# Found 'Contenu des Cours' in Master Télécommunications, Réseaux et Sécurité
# Flushing Doctorat Master: Master Télécommunications, Réseaux et Sécurité
# Finalizing course: MTRS01S1
# Finalizing course: MTRS07S1
# Finalizing course: MTRS05S1
# Finalizing course: MTRS14S1
# Finalizing course: MTRS10S1
# Finalizing course: MTRS01S2
# Finalizing course: MTRS12S1
# Finalizing course: MTRS02S1
# Finalizing course: MTRS04S1
# Finalizing course: MTRS09S1
# Finalizing course: MTRS06S1
# Finalizing course: MTRS13S1
# Finalizing course: MTRS11S1
# Finalizing course: MTRS03S1
# Finalizing course: MTRS08S1
# New department: CINET : Centre des Industries Électriques et des Télécommunications (NUD)
# Checking header for courses: ### responsable : elias rachid
# Checking header for courses: ### membres
# Checking header for courses: ### mission
# Checking header for courses: ### laboratoires et locaux
# Checking header for courses: ### horaire d’ouverture
# Checking header for courses: ### services
# Checking header for courses: ### thématiques de recherche
# New department: CLERC : Centre Libanais d’Etudes et de Recherches de la Construction
# Checking header for courses: ### responsable : fouad kaddah
# Checking header for courses: ### membres
# Checking header for courses: ### mission
# Checking header for courses: ### laboratoires et locaux
# Checking header for courses: ### horaire d’ouverture
# Checking header for courses: ### services
# Checking header for courses: ### thématiques de recherche
# New department: CIMTI : Centre d'Informatique, de Modélisation et de Technologies de l'Information (NUD)
# Checking header for courses: ### responsable : samer lahoud
# Checking header for courses: ### membres
# Checking header for courses: ### mission du cimti
# Checking header for courses: ### laboratoires et locaux
# Checking header for courses: ### horaire d’ouverture
# Checking header for courses: ### services
# Checking header for courses: ### thématiques de recherche
# Checking header for courses: ### projets de recherche en cours
# Checking header for courses: ### collaborations et partenariats
# ✅ Extracted courses from 9 departments.
